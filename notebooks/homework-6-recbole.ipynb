# %%
import ast
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle

import warnings
warnings.filterwarnings('ignore')

from collections import Counter
from random import randint, random
from scipy.sparse import coo_matrix, hstack
from sklearn.metrics.pairwise import euclidean_distances, cosine_distances, cosine_similarity

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
interactions_df = pd.read_csv('/kaggle/input/kion-processed/interactions_processed_kion.csv')
users_df = pd.read_csv('/kaggle/input/kion-processed/users_processed_kion.csv')
items_df = pd.read_csv('/kaggle/input/kion-processed/items_processed_kion.csv')

# %%
interactions_df['t_dat'] = pd.to_datetime(interactions_df['last_watch_dt'], format="%Y-%m-%d")
interactions_df['timestamp'] = interactions_df.t_dat.values.astype(np.int64) // 10 ** 9

# %%
df = interactions_df[['user_id', 'item_id', 'timestamp']].rename(
    columns={'user_id': 'user_id:token', 'item_id': 'item_id:token', 'timestamp': 'timestamp:float'})

# %%
df
# Out:
#          user_id:token  item_id:token  timestamp:float
# 0               176549           9506       1620691200
# 1               699317           1659       1622246400
# 2               656683           7107       1620518400
# 3               864613           7638       1625443200
# 4               964868           9506       1619740800
# ...                ...            ...              ...
# 5476246         648596          12225       1628812800
# 5476247         546862           9673       1618272000
# 5476248         697262          15297       1629417600
# 5476249         384202          16197       1618790400
# 5476250         319709           4436       1628985600
#
# [5476251 rows x 3 columns]

# %%
# !mkdir recbox_data

# %%
df.to_csv('recbox_data/recbox_data.inter', index=False, sep='\t')

# %%
import logging
from logging import getLogger
from recbole.config import Config
from recbole.data import create_dataset, data_preparation
from recbole.model.sequential_recommender import GRU4Rec, Caser
from recbole.trainer import Trainer
from recbole.utils import init_seed, init_logger
from recbole.quick_start import run_recbole

# %%
parameter_dict = {
    'data_path': '',
    'USER_ID_FIELD': 'user_id',
    'ITEM_ID_FIELD': 'item_id',
    'TIME_FIELD': 'timestamp',
    'device': 'GPU',
    'user_inter_num_interval': "[40,inf)",
    'item_inter_num_interval': "[40,inf)",
    'load_col': {'inter': ['user_id', 'item_id', 'timestamp']},
    'neg_sampling': None,
    'epochs': 10,
    'verbose': -1,
    'show_progress' : False,
    'eval_args': {
        'split': {'RS': [9, 0, 1]},
        'group_by': 'user',
        'order': 'TO',
        'mode': 'full'}
}
config = Config(model='MultiVAE', dataset='recbox_data', config_dict=parameter_dict)

# init random seed
init_seed(config['seed'], config['reproducibility'])

# logger initialization
init_logger(config)
logger = getLogger()
# Create handlers
c_handler = logging.StreamHandler()
c_handler.setLevel(logging.INFO)
logger.addHandler(c_handler)

# write config info into log
# logger.info(config)

# %%
dataset = create_dataset(config)
logger.info(dataset)
# Out:
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']

# %%
# dataset splitting
train_data, valid_data, test_data = data_preparation(config, dataset)
# Out:
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]

# %%
import time

# %% [markdown]
# ### Попробую несколько разных архитектур за разные года

# %%
# %%time
model_list = [ "LightGCN", "MultiVAE", "RecVAE"] 

for model_name in model_list:
    print(f"running {model_name}...")
    start = time.time()
    result = run_recbole(model=model_name, dataset = 'recbox_data',config_dict = parameter_dict)
    t = time.time() - start
    print(f"It took {t/60:.2f} mins")
    print(result)
# Out:
# running LightGCN...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# n_layers = 2
# reg_weight = 1e-05
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# n_layers = 2
# reg_weight = 1e-05
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# LightGCN(
#   (user_embedding): Embedding(13355, 64)
#   (item_embedding): Embedding(3294, 64)
#   (mf_loss): BPRLoss()
#   (reg_loss): EmbLoss()
# )
# Trainable parameters: 1065536
# LightGCN(
#   (user_embedding): Embedding(13355, 64)
#   (item_embedding): Embedding(3294, 64)
#   (mf_loss): BPRLoss()
#   (reg_loss): EmbLoss()
# )
# Trainable parameters: 1065536
# FLOPs: 0.0
# FLOPs: 0.0
# epoch 0 training [time: 15.35s, train loss: 201.8552]
# epoch 0 training [time: 15.35s, train loss: 201.8552]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 1 training [time: 15.04s, train loss: 166.0586]
# epoch 1 training [time: 15.04s, train loss: 166.0586]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 2 training [time: 14.91s, train loss: 156.0221]
# epoch 2 training [time: 14.91s, train loss: 156.0221]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 3 training [time: 15.14s, train loss: 149.5909]
# epoch 3 training [time: 15.14s, train loss: 149.5909]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 4 training [time: 14.81s, train loss: 146.1851]
# epoch 4 training [time: 14.81s, train loss: 146.1851]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 5 training [time: 15.12s, train loss: 143.7300]
# epoch 5 training [time: 15.12s, train loss: 143.7300]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 6 training [time: 14.93s, train loss: 141.2300]
# epoch 6 training [time: 14.93s, train loss: 141.2300]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 7 training [time: 15.03s, train loss: 137.4872]
# epoch 7 training [time: 15.03s, train loss: 137.4872]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 8 training [time: 14.85s, train loss: 133.3195]
# epoch 8 training [time: 14.85s, train loss: 133.3195]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# epoch 9 training [time: 15.07s, train loss: 129.4056]
# epoch 9 training [time: 15.07s, train loss: 129.4056]
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Saving current: saved/LightGCN-Jan-22-2023_18-06-29.pth
# Loading model structure and parameters from saved/LightGCN-Jan-22-2023_18-06-29.pth
# Loading model structure and parameters from saved/LightGCN-Jan-22-2023_18-06-29.pth
# best valid : None
# best valid : None
# test result: OrderedDict([('recall@10', 0.0792), ('mrr@10', 0.1685), ('ndcg@10', 0.0795), ('hit@10', 0.3385), ('precision@10', 0.0441)])
# test result: OrderedDict([('recall@10', 0.0792), ('mrr@10', 0.1685), ('ndcg@10', 0.0795), ('hit@10', 0.3385), ('precision@10', 0.0441)])
# It took 3.48 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0792), ('mrr@10', 0.1685), ('ndcg@10', 0.0795), ('hit@10', 0.3385), ('precision@10', 0.0441)])}
# running MultiVAE...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4072622
# MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4072622
# FLOPs: 4068000.0
# FLOPs: 4068000.0
# epoch 0 training [time: 0.18s, train loss: 3249.2598]
# epoch 0 training [time: 0.18s, train loss: 3249.2598]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 1 training [time: 0.18s, train loss: 3098.9068]
# epoch 1 training [time: 0.18s, train loss: 3098.9068]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 2 training [time: 0.17s, train loss: 3045.3319]
# epoch 2 training [time: 0.17s, train loss: 3045.3319]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 3 training [time: 0.17s, train loss: 3007.5465]
# epoch 3 training [time: 0.17s, train loss: 3007.5465]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 4 training [time: 0.18s, train loss: 2949.2036]
# epoch 4 training [time: 0.18s, train loss: 2949.2036]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 5 training [time: 0.17s, train loss: 2917.9035]
# epoch 5 training [time: 0.17s, train loss: 2917.9035]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 6 training [time: 0.21s, train loss: 2897.4790]
# epoch 6 training [time: 0.21s, train loss: 2897.4790]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 7 training [time: 0.23s, train loss: 2885.6975]
# epoch 7 training [time: 0.23s, train loss: 2885.6975]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 8 training [time: 0.30s, train loss: 2872.3692]
# epoch 8 training [time: 0.30s, train loss: 2872.3692]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# epoch 9 training [time: 0.19s, train loss: 2851.3863]
# epoch 9 training [time: 0.19s, train loss: 2851.3863]
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Saving current: saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Loading model structure and parameters from saved/MultiVAE-Jan-22-2023_18-09-54.pth
# Loading model structure and parameters from saved/MultiVAE-Jan-22-2023_18-09-54.pth
# best valid : None
# best valid : None
# test result: OrderedDict([('recall@10', 0.0839), ('mrr@10', 0.168), ('ndcg@10', 0.082), ('hit@10', 0.3487), ('precision@10', 0.0465)])
# test result: OrderedDict([('recall@10', 0.0839), ('mrr@10', 0.168), ('ndcg@10', 0.082), ('hit@10', 0.3487), ('precision@10', 0.0465)])
# It took 1.09 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0839), ('mrr@10', 0.168), ('ndcg@10', 0.082), ('hit@10', 0.3487), ('precision@10', 0.0465)])}
# running RecVAE...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# hidden_dimension = 600
# latent_dimension = 200
# dropout_prob = 0.5
# beta = 0.2
# gamma = 0.005
# mixture_weights = [0.15, 0.75, 0.1]
# n_enc_epochs = 3
# n_dec_epochs = 1
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# hidden_dimension = 600
# latent_dimension = 200
# dropout_prob = 0.5
# beta = 0.2
# gamma = 0.005
# mixture_weights = [0.15, 0.75, 0.1]
# n_enc_epochs = 3
# n_dec_epochs = 1
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# RecVAE(
#   (encoder): Encoder(
#     (fc1): Linear(in_features=3294, out_features=600, bias=True)
#     (ln1): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc2): Linear(in_features=600, out_features=600, bias=True)
#     (ln2): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc3): Linear(in_features=600, out_features=600, bias=True)
#     (ln3): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc4): Linear(in_features=600, out_features=600, bias=True)
#     (ln4): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc5): Linear(in_features=600, out_features=600, bias=True)
#     (ln5): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc_mu): Linear(in_features=600, out_features=200, bias=True)
#     (fc_logvar): Linear(in_features=600, out_features=200, bias=True)
#   )
#   (prior): CompositePrior(
#     (encoder_old): Encoder(
#       (fc1): Linear(in_features=3294, out_features=600, bias=True)
#       (ln1): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc2): Linear(in_features=600, out_features=600, bias=True)
#       (ln2): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc3): Linear(in_features=600, out_features=600, bias=True)
#       (ln3): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc4): Linear(in_features=600, out_features=600, bias=True)
#       (ln4): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc5): Linear(in_features=600, out_features=600, bias=True)
#       (ln5): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc_mu): Linear(in_features=600, out_features=200, bias=True)
#       (fc_logvar): Linear(in_features=600, out_features=200, bias=True)
#     )
#   )
#   (decoder): Linear(in_features=200, out_features=3294, bias=True)
# )
# Trainable parameters: 4327894
# RecVAE(
#   (encoder): Encoder(
#     (fc1): Linear(in_features=3294, out_features=600, bias=True)
#     (ln1): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc2): Linear(in_features=600, out_features=600, bias=True)
#     (ln2): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc3): Linear(in_features=600, out_features=600, bias=True)
#     (ln3): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc4): Linear(in_features=600, out_features=600, bias=True)
#     (ln4): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc5): Linear(in_features=600, out_features=600, bias=True)
#     (ln5): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc_mu): Linear(in_features=600, out_features=200, bias=True)
#     (fc_logvar): Linear(in_features=600, out_features=200, bias=True)
#   )
#   (prior): CompositePrior(
#     (encoder_old): Encoder(
#       (fc1): Linear(in_features=3294, out_features=600, bias=True)
#       (ln1): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc2): Linear(in_features=600, out_features=600, bias=True)
#       (ln2): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc3): Linear(in_features=600, out_features=600, bias=True)
#       (ln3): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc4): Linear(in_features=600, out_features=600, bias=True)
#       (ln4): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc5): Linear(in_features=600, out_features=600, bias=True)
#       (ln5): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc_mu): Linear(in_features=600, out_features=200, bias=True)
#       (fc_logvar): Linear(in_features=600, out_features=200, bias=True)
#     )
#   )
#   (decoder): Linear(in_features=200, out_features=3294, bias=True)
# )
# Trainable parameters: 4327894
# FLOPs: 4321200.0
# FLOPs: 4321200.0
# epoch 0 training [time: 1.85s, train loss: 2355.0183]
# epoch 0 training [time: 1.85s, train loss: 2355.0183]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 1 training [time: 1.57s, train loss: 2248.6090]
# epoch 1 training [time: 1.57s, train loss: 2248.6090]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 2 training [time: 1.41s, train loss: 2186.4757]
# epoch 2 training [time: 1.41s, train loss: 2186.4757]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 3 training [time: 1.40s, train loss: 2147.2895]
# epoch 3 training [time: 1.40s, train loss: 2147.2895]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 4 training [time: 1.59s, train loss: 2109.0774]
# epoch 4 training [time: 1.59s, train loss: 2109.0774]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 5 training [time: 1.39s, train loss: 2076.2603]
# epoch 5 training [time: 1.39s, train loss: 2076.2603]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 6 training [time: 1.42s, train loss: 2045.4687]
# epoch 6 training [time: 1.42s, train loss: 2045.4687]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 7 training [time: 1.38s, train loss: 2017.4943]
# epoch 7 training [time: 1.38s, train loss: 2017.4943]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 8 training [time: 1.45s, train loss: 2001.5762]
# epoch 8 training [time: 1.45s, train loss: 2001.5762]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# epoch 9 training [time: 1.40s, train loss: 1977.0179]
# epoch 9 training [time: 1.40s, train loss: 1977.0179]
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Saving current: saved/RecVAE-Jan-22-2023_18-10-59.pth
# Loading model structure and parameters from saved/RecVAE-Jan-22-2023_18-10-59.pth
# Loading model structure and parameters from saved/RecVAE-Jan-22-2023_18-10-59.pth
# best valid : None
# best valid : None
# test result: OrderedDict([('recall@10', 0.0851), ('mrr@10', 0.168), ('ndcg@10', 0.0825), ('hit@10', 0.3529), ('precision@10', 0.047)])
# test result: OrderedDict([('recall@10', 0.0851), ('mrr@10', 0.168), ('ndcg@10', 0.0825), ('hit@10', 0.3529), ('precision@10', 0.047)])
# It took 1.39 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0851), ('mrr@10', 0.168), ('ndcg@10', 0.0825), ('hit@10', 0.3529), ('precision@10', 0.047)])}
# CPU times: user 5min 34s, sys: 19.4 s, total: 5min 54s
# Wall time: 5min 57s

# %%
# %%time
model_list = ["CORE", "LightSANs", "NextItNet",] 

parameter_dict["train_neg_sample_args"] = None

for model_name in model_list:
    print(f"running {model_name}...")
    start = time.time()
    result = run_recbole(model=model_name, dataset = 'recbox_data', config_dict = parameter_dict)
    t = time.time() - start
    print(f"It took {t/60:.2f} mins")
    print(result)
# Out:
# running CORE...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# inner_size = 256
# n_layers = 2
# n_heads = 2
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.5
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# loss_type = CE
# dnn_type = trm
# sess_dropout = 0.2
# item_dropout = 0.2
# temperature = 0.07
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# inner_size = 256
# n_layers = 2
# n_heads = 2
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.5
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# loss_type = CE
# dnn_type = trm
# sess_dropout = 0.2
# item_dropout = 0.2
# temperature = 0.07
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# CORE(
#   (sess_dropout): Dropout(p=0.2, inplace=False)
#   (item_dropout): Dropout(p=0.2, inplace=False)
#   (item_embedding): Embedding(3294, 64, padding_idx=0)
#   (net): TransNet(
#     (position_embedding): Embedding(50, 64)
#     (trm_encoder): TransformerEncoder(
#       (layer): ModuleList(
#         (0): TransformerLayer(
#           (multi_head_attention): MultiHeadAttention(
#             (query): Linear(in_features=64, out_features=64, bias=True)
#             (key): Linear(in_features=64, out_features=64, bias=True)
#             (value): Linear(in_features=64, out_features=64, bias=True)
#             (softmax): Softmax(dim=-1)
#             (attn_dropout): Dropout(p=0.5, inplace=False)
#             (dense): Linear(in_features=64, out_features=64, bias=True)
#             (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#             (out_dropout): Dropout(p=0.5, inplace=False)
#           )
#           (feed_forward): FeedForward(
#             (dense_1): Linear(in_features=64, out_features=256, bias=True)
#             (dense_2): Linear(in_features=256, out_features=64, bias=True)
#             (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.5, inplace=False)
#           )
#         )
#         (1): TransformerLayer(
#           (multi_head_attention): MultiHeadAttention(
#             (query): Linear(in_features=64, out_features=64, bias=True)
#             (key): Linear(in_features=64, out_features=64, bias=True)
#             (value): Linear(in_features=64, out_features=64, bias=True)
#             (softmax): Softmax(dim=-1)
#             (attn_dropout): Dropout(p=0.5, inplace=False)
#             (dense): Linear(in_features=64, out_features=64, bias=True)
#             (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#             (out_dropout): Dropout(p=0.5, inplace=False)
#           )
#           (feed_forward): FeedForward(
#             (dense_1): Linear(in_features=64, out_features=256, bias=True)
#             (dense_2): Linear(in_features=256, out_features=64, bias=True)
#             (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.5, inplace=False)
#           )
#         )
#       )
#     )
#     (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#     (fn): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 314177
# CORE(
#   (sess_dropout): Dropout(p=0.2, inplace=False)
#   (item_dropout): Dropout(p=0.2, inplace=False)
#   (item_embedding): Embedding(3294, 64, padding_idx=0)
#   (net): TransNet(
#     (position_embedding): Embedding(50, 64)
#     (trm_encoder): TransformerEncoder(
#       (layer): ModuleList(
#         (0): TransformerLayer(
#           (multi_head_attention): MultiHeadAttention(
#             (query): Linear(in_features=64, out_features=64, bias=True)
#             (key): Linear(in_features=64, out_features=64, bias=True)
#             (value): Linear(in_features=64, out_features=64, bias=True)
#             (softmax): Softmax(dim=-1)
#             (attn_dropout): Dropout(p=0.5, inplace=False)
#             (dense): Linear(in_features=64, out_features=64, bias=True)
#             (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#             (out_dropout): Dropout(p=0.5, inplace=False)
#           )
#           (feed_forward): FeedForward(
#             (dense_1): Linear(in_features=64, out_features=256, bias=True)
#             (dense_2): Linear(in_features=256, out_features=64, bias=True)
#             (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.5, inplace=False)
#           )
#         )
#         (1): TransformerLayer(
#           (multi_head_attention): MultiHeadAttention(
#             (query): Linear(in_features=64, out_features=64, bias=True)
#             (key): Linear(in_features=64, out_features=64, bias=True)
#             (value): Linear(in_features=64, out_features=64, bias=True)
#             (softmax): Softmax(dim=-1)
#             (attn_dropout): Dropout(p=0.5, inplace=False)
#             (dense): Linear(in_features=64, out_features=64, bias=True)
#             (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#             (out_dropout): Dropout(p=0.5, inplace=False)
#           )
#           (feed_forward): FeedForward(
#             (dense_1): Linear(in_features=64, out_features=256, bias=True)
#             (dense_2): Linear(in_features=256, out_features=64, bias=True)
#             (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.5, inplace=False)
#           )
#         )
#       )
#     )
#     (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#     (fn): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 314177
# FLOPs: 4986664.0
# FLOPs: 4986664.0
# epoch 0 training [time: 53.43s, train loss: 3014.4871]
# epoch 0 training [time: 53.43s, train loss: 3014.4871]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 1 training [time: 54.11s, train loss: 2695.8827]
# epoch 1 training [time: 54.11s, train loss: 2695.8827]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 2 training [time: 54.32s, train loss: 2613.5933]
# epoch 2 training [time: 54.32s, train loss: 2613.5933]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 3 training [time: 54.04s, train loss: 2579.4703]
# epoch 3 training [time: 54.04s, train loss: 2579.4703]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 4 training [time: 54.49s, train loss: 2561.8123]
# epoch 4 training [time: 54.49s, train loss: 2561.8123]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 5 training [time: 54.32s, train loss: 2551.0908]
# epoch 5 training [time: 54.32s, train loss: 2551.0908]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 6 training [time: 54.41s, train loss: 2545.2349]
# epoch 6 training [time: 54.41s, train loss: 2545.2349]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 7 training [time: 53.52s, train loss: 2540.1147]
# epoch 7 training [time: 53.52s, train loss: 2540.1147]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 8 training [time: 53.88s, train loss: 2537.2359]
# epoch 8 training [time: 53.88s, train loss: 2537.2359]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# epoch 9 training [time: 54.58s, train loss: 2534.1025]
# epoch 9 training [time: 54.58s, train loss: 2534.1025]
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Saving current: saved/CORE-Jan-22-2023_18-15-44.pth
# Loading model structure and parameters from saved/CORE-Jan-22-2023_18-15-44.pth
# Loading model structure and parameters from saved/CORE-Jan-22-2023_18-15-44.pth
# best valid : None
# best valid : None
# test result: OrderedDict([('recall@10', 0.0932), ('mrr@10', 0.0296), ('ndcg@10', 0.0442), ('hit@10', 0.0932), ('precision@10', 0.0093)])
# test result: OrderedDict([('recall@10', 0.0932), ('mrr@10', 0.0296), ('ndcg@10', 0.0442), ('hit@10', 0.0932), ('precision@10', 0.0093)])
# It took 9.98 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0932), ('mrr@10', 0.0296), ('ndcg@10', 0.0442), ('hit@10', 0.0932), ('precision@10', 0.0093)])}
# running LightSANs...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# k_interests = 5
# n_layers = 2
# n_heads = 2
# hidden_size = 64
# inner_size = 256
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.5
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# k_interests = 5
# n_layers = 2
# n_heads = 2
# hidden_size = 64
# inner_size = 256
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.5
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# LightSANs(
#   (item_embedding): Embedding(3294, 64, padding_idx=0)
#   (position_embedding): Embedding(50, 64)
#   (trm_encoder): LightTransformerEncoder(
#     (layer): ModuleList(
#       (0): LightTransformerLayer(
#         (multi_head_attention): LightMultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (attpooling_key): ItemToInterestAggregation()
#           (attpooling_value): ItemToInterestAggregation()
#           (pos_q_linear): Linear(in_features=64, out_features=64, bias=True)
#           (pos_k_linear): Linear(in_features=64, out_features=64, bias=True)
#           (pos_ln): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (1): LightTransformerLayer(
#         (multi_head_attention): LightMultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (attpooling_key): ItemToInterestAggregation()
#           (attpooling_value): ItemToInterestAggregation()
#           (pos_q_linear): Linear(in_features=64, out_features=64, bias=True)
#           (pos_k_linear): Linear(in_features=64, out_features=64, bias=True)
#           (pos_ln): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 332288
# LightSANs(
#   (item_embedding): Embedding(3294, 64, padding_idx=0)
#   (position_embedding): Embedding(50, 64)
#   (trm_encoder): LightTransformerEncoder(
#     (layer): ModuleList(
#       (0): LightTransformerLayer(
#         (multi_head_attention): LightMultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (attpooling_key): ItemToInterestAggregation()
#           (attpooling_value): ItemToInterestAggregation()
#           (pos_q_linear): Linear(in_features=64, out_features=64, bias=True)
#           (pos_k_linear): Linear(in_features=64, out_features=64, bias=True)
#           (pos_ln): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (1): LightTransformerLayer(
#         (multi_head_attention): LightMultiHeadAttention(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (attpooling_key): ItemToInterestAggregation()
#           (attpooling_value): ItemToInterestAggregation()
#           (pos_q_linear): Linear(in_features=64, out_features=64, bias=True)
#           (pos_k_linear): Linear(in_features=64, out_features=64, bias=True)
#           (pos_ln): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (attn_dropout): Dropout(p=0.5, inplace=False)
#           (dense): Linear(in_features=64, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=64, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=64, bias=True)
#           (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 332288
# FLOPs: 5785664.0
# FLOPs: 5785664.0
# epoch 0 training [time: 74.14s, train loss: 2746.9818]
# epoch 0 training [time: 74.14s, train loss: 2746.9818]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 1 training [time: 73.07s, train loss: 2593.4830]
# epoch 1 training [time: 73.07s, train loss: 2593.4830]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 2 training [time: 73.51s, train loss: 2552.7213]
# epoch 2 training [time: 73.51s, train loss: 2552.7213]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 3 training [time: 73.68s, train loss: 2530.1587]
# epoch 3 training [time: 73.68s, train loss: 2530.1587]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 4 training [time: 73.19s, train loss: 2517.0460]
# epoch 4 training [time: 73.19s, train loss: 2517.0460]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 5 training [time: 73.43s, train loss: 2507.4446]
# epoch 5 training [time: 73.43s, train loss: 2507.4446]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 6 training [time: 73.66s, train loss: 2500.7219]
# epoch 6 training [time: 73.66s, train loss: 2500.7219]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 7 training [time: 73.96s, train loss: 2495.5117]
# epoch 7 training [time: 73.96s, train loss: 2495.5117]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 8 training [time: 73.86s, train loss: 2490.8590]
# epoch 8 training [time: 73.86s, train loss: 2490.8590]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# epoch 9 training [time: 74.38s, train loss: 2487.2821]
# epoch 9 training [time: 74.38s, train loss: 2487.2821]
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Saving current: saved/LightSANs-Jan-22-2023_18-25-41.pth
# Loading model structure and parameters from saved/LightSANs-Jan-22-2023_18-25-41.pth
# Loading model structure and parameters from saved/LightSANs-Jan-22-2023_18-25-41.pth
# best valid : None
# best valid : None
# test result: OrderedDict([('recall@10', 0.1038), ('mrr@10', 0.0368), ('ndcg@10', 0.0523), ('hit@10', 0.1038), ('precision@10', 0.0104)])
# test result: OrderedDict([('recall@10', 0.1038), ('mrr@10', 0.0368), ('ndcg@10', 0.0523), ('hit@10', 0.1038), ('precision@10', 0.0104)])
# It took 13.22 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.1038), ('mrr@10', 0.0368), ('ndcg@10', 0.0523), ('hit@10', 0.1038), ('precision@10', 0.0104)])}
# running NextItNet...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-9a237c84-d3ee-4a0c-b615-f6fbe2099985.json']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# kernel_size = 3
# block_num = 5
# dilations = [1, 4]
# reg_weight = 1e-05
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = False
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# kernel_size = 3
# block_num = 5
# dilations = [1, 4]
# reg_weight = 1e-05
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# device = cuda
# neg_sampling = None
# verbose = -1
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# NextItNet(
#   (item_embedding): Embedding(3294, 64, padding_idx=0)
#   (residual_blocks): Sequential(
#     (0): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (1): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (2): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (3): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (4): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (5): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (6): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (7): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (8): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (9): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#   )
#   (final_layer): Linear(in_features=64, out_features=64, bias=True)
#   (loss_fct): CrossEntropyLoss()
#   (reg_loss): RegLoss()
# )
# Trainable parameters: 464576
# NextItNet(
#   (item_embedding): Embedding(3294, 64, padding_idx=0)
#   (residual_blocks): Sequential(
#     (0): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (1): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (2): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (3): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (4): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (5): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (6): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (7): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (8): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(2, 2))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#     (9): ResidualBlock_b(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(4, 4))
#       (ln1): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), dilation=(8, 8))
#       (ln2): LayerNorm((64,), eps=1e-08, elementwise_affine=True)
#     )
#   )
#   (final_layer): Linear(in_features=64, out_features=64, bias=True)
#   (loss_fct): CrossEntropyLoss()
#   (reg_loss): RegLoss()
# )
# Trainable parameters: 464576
# FLOPs: 12423360.0
# FLOPs: 12423360.0
# epoch 0 training [time: 319.76s, train loss: 2734.1275]
# epoch 0 training [time: 319.76s, train loss: 2734.1275]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 1 training [time: 319.35s, train loss: 2605.7013]
# epoch 1 training [time: 319.35s, train loss: 2605.7013]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 2 training [time: 319.31s, train loss: 2556.8204]
# epoch 2 training [time: 319.31s, train loss: 2556.8204]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 3 training [time: 319.36s, train loss: 2530.6368]
# epoch 3 training [time: 319.36s, train loss: 2530.6368]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 4 training [time: 319.34s, train loss: 2512.6447]
# epoch 4 training [time: 319.34s, train loss: 2512.6447]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 5 training [time: 320.11s, train loss: 2497.8835]
# epoch 5 training [time: 320.11s, train loss: 2497.8835]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 6 training [time: 319.25s, train loss: 2485.2415]
# epoch 6 training [time: 319.25s, train loss: 2485.2415]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 7 training [time: 319.18s, train loss: 2475.8000]
# epoch 7 training [time: 319.18s, train loss: 2475.8000]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 8 training [time: 319.17s, train loss: 2466.7220]
# epoch 8 training [time: 319.17s, train loss: 2466.7220]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# epoch 9 training [time: 319.16s, train loss: 2457.8243]
# epoch 9 training [time: 319.16s, train loss: 2457.8243]
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Saving current: saved/NextItNet-Jan-22-2023_18-38-59.pth
# Loading model structure and parameters from saved/NextItNet-Jan-22-2023_18-38-59.pth
# Loading model structure and parameters from saved/NextItNet-Jan-22-2023_18-38-59.pth
# best valid : None
# best valid : None
# test result: OrderedDict([('recall@10', 0.094), ('mrr@10', 0.0333), ('ndcg@10', 0.0473), ('hit@10', 0.094), ('precision@10', 0.0094)])
# test result: OrderedDict([('recall@10', 0.094), ('mrr@10', 0.0333), ('ndcg@10', 0.0473), ('hit@10', 0.094), ('precision@10', 0.0094)])
# It took 54.45 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.094), ('mrr@10', 0.0333), ('ndcg@10', 0.0473), ('hit@10', 0.094), ('precision@10', 0.0094)])}
# CPU times: user 1h 14min 12s, sys: 3min 2s, total: 1h 17min 14s
# Wall time: 1h 17min 39s

# %% [markdown]
# Без должной настройки и подбора гипперпараметров современные продвинутые модели из коробки не могут пробить автоэнкодеры.
